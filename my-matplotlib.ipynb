# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# **`.plot(x,y, parameters)`**
#
# | Parameter | Short Form | Possible Values / Examples |
# |---|---|---|
# | color | c | `'r'`, `'g'`, `'b'`, `'black'`, `'yellow'`, `'cyan'`, `'magenta'` |
# | linewidth | lw | Any number like `1`, `2`, `5` |
# | linestyle | ls | `'-'`, `'--'`, `':'`, `'-.'` |
# | marker | — | `'o'`, `'*'`, `'+'`, `'x'`, `'s'`, `'^'`, `'D'` |
# | markersize | ms | Any number like `5`, `10`, `15` |
# | markerfacecolor | mfc | Any valid color |
# | markeredgecolor | mec | Any valid color |
# | label | — | Any string like `'Sales'`, `'Profit'` |
# | alpha | — | `0` to `1` |
# | drawstyle | — | `'default'`, `'steps'`, `'steps-pre'`, `'steps-mid'`, `'steps-post'` |
# | zorder | — | Any integer like `1`, `5`, `10` |
# | visible | — | `True`, `False` |
# | antialiased | aa | `True`, `False` |
# | dash_capstyle | — | `'butt'`, `'round'`, `'projecting'` |
# | solid_capstyle | — | `'butt'`, `'round'`, `'projecting'` |
# | animated | — | `True`, `False` |
# | picker | — | `True`, `False` |
# | scalex | — | `True`, `False` |
# | scaley | — | `True`, `False` |
#
# ---
#
# #### Format String Examples
#
# | Format String | Meaning |
# |---|---|
# | `'ro--'` | Red + Circle + Dashed |
# | `'g^:'` | Green + Triangle + Dotted |
# | `'bs-'` | Blue + Square + Solid |
# | `'mx-.'` | Magenta + X Marker + Dash-dot |
#
#
# **`legend()`**: to show the labels passed during  plot()
#
# **`show()`**: show the plots
#
# **`title()`**: title of the plot
#
# **`xlabel()`**: labels for x axis
#
# **`ylabel()`**: labels for the y axis
#
# **`xticks(arr)`**: x axis dustribution
#
# **`ticks_params(axis)`**: modify ticks
#
# **`grid(axis='both',params)`**

# %%
x = [2023,2024,2025,2026]
y1 = [20,27,25,26]
y2 = [15,5,26,32]
y3 = [17,20,12,23]

plt.title('class size',
          fontsize=16,
          fontweight='bold',
          color='black')

plt.xlabel('year',
           fontsize=10,
           color='#870017',
           fontstyle='italic')

plt.ylabel('students',
           color='#870017',
           fontsize=10,
           fontstyle='italic')

line_style = dict(c='#040169',
                  ls='None',
                  marker='x',
                  ms=10,
                  mfc='black',
                  mec='black',
                  alpha=1,
                  zorder=3)

plt.xticks(x)
plt.tick_params(axis='both',
                colors='blue')

plot1 = plt.plot(x, y1, c='#dea004',lw=2,ls='--',marker='o',ms=7,mfc='white',mec='black',label='sample1',alpha=0.9, drawstyle='default',zorder=1)
plot2 = plt.plot(x,y2,**line_style,label='sample2')
plot3 = plt.plot(x,y3,'k^-.',alpha=0.7,zorder=2,label='sample3',lw=2)

plt.grid(axis='both',
         lw=0.5,
         color='purple',
         linestyle='--',
         alpha=0.5,
         )
plt.legend()
plt.show()

# %% [markdown]
# #### *BARPLOTS*
#
# **`bar()`**
#
# - bottom, align
#
# **`xticks()`**
#
# **`yticks()`**

# %%
genre = ['Drama','Comedy','Horror','SciFi','RomCom','Action']
india = np.array([23,10,13,32,20,25])
us = np.array([13,12,23,29,10,35])

param = {'color':'#032a69',
         'alpha':0.6,
         'edgecolor':'black',
         'lw':1,
         'bottom':5,
         'align':'edge'
        }

movieGenre_indians = plt.bar(genre,india,**param,label='Indian')
movieGenre_us = plt.bar(genre,us,label='us',color='orange',bottom=5,align='edge',edgecolor='black',lw=1,alpha=0.5)

plt.legend()
plt.xlabel('GENRES',fontstyle='italic')
plt.ylabel('Number of Movies',fontstyle='italic')
plt.title('MOVIE DISTRIBUTION',fontsize=18,fontweight='bold')
plt.tick_params(axis='both',color='black')
plt.xticks(color='gray')
plt.yticks(color='gray')
plt.show()

# %%
genre = ['Drama','Comedy','Horror','SciFi','RomCom','Action']
india = np.array([23,10,13,32,20,25])
us = np.array([13,12,23,29,10,35])

param = {'color':'#032a69',
         'alpha':0.6,
         'edgecolor':'black',
         'lw':1,
         'align':'edge'
        }

movieGenre_indians = plt.barh(genre,india,**param,label='Indian')
movieGenre_us = plt.barh(genre,us,label='us',color='orange',align='edge',edgecolor='black',lw=1,alpha=0.5)

plt.legend()
plt.xlabel('Number of Movies',fontstyle='italic')
plt.ylabel('GENRE',fontstyle='italic')
plt.title('MOVIE DISTRIBUTION',fontsize=18,fontweight='bold')
plt.tick_params(axis='both',color='black')
plt.xticks(color='gray')
plt.yticks(color='gray')
plt.show()

# %% [markdown]
# #### *PIEPLOTS*
#
# - labels, colors, autopct, explode, shadow, startangle, radius, wedgeprops

# %%
genre = ['Drama','Comedy','Horror','SciFi','RomCom','Action']
india = np.array([23,10,13,32,20,25])
us = np.array([13,12,23,29,10,35])

color1 = ['#eb983b','#3bdfeb','#eb3b3e','#ebc23b','#3b93eb','#3beb6f']
color2 = ['#3bdfeb','#ebc23b','#eb983b','#3beb6f',"#026c74",'#eb3b3e']

movieGenre_indians = plt.pie(india,
                             labels=genre,
                             autopct="%1.1f%%",
                             colors=color1,
                             explode=[0,0,0,0.1,0,0],
                             shadow=True,
                             startangle=180,
                             radius=1,
                             wedgeprops={'width':0.3,'edgecolor':'w'}
                            )
movieGenre_us = plt.pie(us,
                        colors=color2,
                        startangle=180,
                        radius=1-0.3,
                        wedgeprops={'width':0.3,'edgecolor':'w','lw':3}
                        )

plt.title('GENRE DISTRIBUTION',fontweight='bold',fontsize=18)
plt.legend()
plt.show()

# %% [markdown]
# #### *SCATTERPLOTS*

# %%
hours = np.array([_ for _ in range(11)])
score1 = np.array([55,60,65,62,68,70,75,78,82,85,87])
score2 = np.array([45,62,65,50,65,69,70,75,80,83,90])

plt.scatter(hours,score1,color='blue',marker='o',lw=1,edgecolor='cyan',s=30,zorder=2,label='class1')
plt.scatter(hours,score2,color='red',marker='o',lw=1,edgecolor='orange',s=30,zorder=1,label='class2')

plt.xlabel("Hours")
plt.ylabel('Scores')
plt.title("Scores and hours", fontsize=20, fontweight='bold')
plt.grid(alpha=0.5,lw=0.7)
plt.legend()
plt.show()
